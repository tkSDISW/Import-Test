# %% [markdown]
# # Populate model from excel

# %%
import capellambse

import ipywidgets as widgets
from IPython.core.display import HTML
import numpy as np
import pandas as pd 
from IPython.display import Markdown


resources = {
    "Import-Test": "Import-Test/Import Test",
}
path_to_model = "../Import Test.aird"
model = capellambse.MelodyModel(path_to_model, resources=resources)

import capellambse_helper #local python module in same directory as notebook needs to be included after model object is created since it patches/extends capabilitits of the model

# %%
import io
from capellambse import decl
la_model = model.la 

capellambse_helper.display_function_property_values(la_model)

capellambse_helper.display_component_property_values(la_model)

#help(la_model.root_component)

# Example system components you want to create

import pandas as pd

import pandas as pd

class ExcelDataFrameReader:
    def __init__(self, file_path):
        """
        Initialize the ExcelDataFrameReader with the path to the Excel file.
        """
        self.file_path = file_path
        self.df = None

    def load_data(self):
        """
        Load the Excel file into a Pandas DataFrame.
        """
        try:
            self.df = pd.read_excel(self.file_path)
            print(f"Data successfully loaded from {self.file_path}")
        except Exception as e:
            print(f"Error loading data: {e}")

    def list_rows(self):
        """
        Iterate through the DataFrame rows and print each row's fields.
        """
        if self.df is not None:
            for index, row in self.df.iterrows():
                print(f"Row {index}:")
                print(f"Tc_Level: {row['Tc_Level']}")
                print(f"Tc_ObjectType: {row['Tc_ObjectType']}")
                print(f"Title: {row['Title']}")
                print("-" * 40)  # Separator for readability
        else:
            print("Data has not been loaded. Please call the 'load_data()' method first.")

    def get_row(self, index):
        """
        Get the row by index as a dictionary.
        """
        if self.df is not None:
            if index < len(self.df):
                return self.df.iloc[index].to_dict()
            else:
                print(f"Index {index} is out of bounds.")
                return None
        else:
            print("Data has not been loaded. Please call the 'load_data()' method first.")
            return None

    def get_column(self, column_name):
        """
        Get all data from a specific column.
        """
        if self.df is not None:
            if column_name in self.df.columns:
                return self.df[column_name].tolist()
            else:
                print(f"Column {column_name} does not exist.")
                return None
        else:
            print("Data has not been loaded. Please call the 'load_data()' method first.")
            return None

    def get_value(self, index, column_name):
        """
        Get a specific value from the DataFrame by row index and column name.
        """
        if self.df is not None:
            if index < len(self.df) and column_name in self.df.columns:
                return self.df.at[index, column_name]
            else:
                print(f"Either index {index} is out of bounds or column {column_name} does not exist.")
                return None
        else:
            print("Data has not been loaded. Please call the 'load_data()' method first.")
            return None

    def get_next_row(self):
        """
        Get the next row starting from the current index and update the current index.
        """
        if self.df is not None:
            if self.current_index < len(self.df):
                self.current_index += 1
                row_data = self.df.iloc[self.current_index].to_dict()
                return None
            else:
                print("No more rows available.")
                return None
        else:
            print("Data has not been loaded. Please call the 'load_data()' method first.")
            return None

    def get_current_row(self):
        """
        Get the row by index as a dictionary.
        """
        if self.df is not None:
            if self.current_index < len(self.df) -1:
                print( self.df.iloc[self.current_index].to_dict()["Title"], "rcl:" ,self.df.iloc[self.current_index].to_dict()["Tc_Level"])
                return self.df.iloc[self.current_index].to_dict()
            else:
                print(f"Index {self.current_index} is out of bounds.")
                print(f"Index providing last row")
                #return self.df.iloc[self.current_index].to_dict()
                return self.df.iloc[len(self.df) -1].to_dict()
        else:
            print("Data has not been loaded. Please call the 'load_data()' method first.")
            return None
    
    def get_first_row(self):
        """
        Reset the pointer to the first row.
        """
        self.current_index = 0
        print("Current row pointer has been reset to the first row.")
        row_data = self.df.iloc[self.current_index].to_dict()
        return row_data
    
    def is_last_row(self):
        """
        Check if the current index points to the last row.
        """
        if self.df is not None:
            return (self.current_index)  == (len(self.df) -1)
        else:
            print("Data has not been loaded. Please call the 'load_data()' method first.")
            return False

# Example usage:
file_path = 'ground vehicle 2.xlsx'  # Replace with your actual path

# Instantiate the class
excel_content = ExcelDataFrameReader(file_path)

# Load the data
excel_content.load_data()

# Access specific row data
row_2 = excel_content.get_row(2)
print(f"Row 2: {row_2}")

# Access a specific column's data
tc_level_column = excel_content.get_column('Tc_Level')
print(f"Tc_Level column: {tc_level_column}")

# Access a specific value from a row and column
value = excel_content.get_value(2, 'Title')
print(f"Value in row 2, 'Title' column: {value}")

#excel_content.list_rows()

def Create_Component_Level(current_level,parent,excel_content):
    print()
    print("Entering","cl",current_level)

    while  excel_content.is_last_row() == False and   int(excel_content.get_current_row()["Tc_Level"]) >= current_level :
        print("row:",excel_content.get_current_row())
        print("last_row",excel_content.is_last_row())
        print("current row :", excel_content.get_current_row()["Title"], "rcl:" ,int(excel_content.get_current_row()["Tc_Level"]),"cl:",current_level)
        
        if   int(excel_content.get_current_row()["Tc_Level"]) > current_level :  #assume only one jump in level.        
            current_level = int(excel_content.get_current_row()["Tc_Level"])
            parent = new_lc                  
            Create_Component_Level(current_level,parent,excel_content)
            current_level = int(excel_content.get_current_row()["Tc_Level"])
        else :
            current_level = int(excel_content.get_current_row()["Tc_Level"])
            new_lc = parent.components.create(name = excel_content.get_current_row()['Title'] )   
            print("created :", excel_content.get_current_row()["Title"])
            excel_content.get_next_row() 
        print()
    print("Exiting",current_level)

parent = la_model.root_component
print(parent)
row = excel_content.get_first_row()
current_level = 0

Create_Component_Level(current_level,parent,excel_content)
# Out:
# Empty DataFrame
# Columns: [Logical Function, Property Value Group Name, Propery Name, Property Value]
# Index: []
# Empty DataFrame
# Columns: [Logical Component, Property Value Group Name, Property Name, Property Value]
# Index: []
# Data successfully loaded from ground vehicle 2.xlsx
# Row 2: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Lead Variant   '}
# Tc_Level column: [0, 1, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 1, 1, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 1, 2, 3, 3, 2, 3, 3, 2, 2, 2, 2, 1, 2, 3, 3, 2, 3, 3, 2, 2, 1, 2, 2, 2, 1, 2, 3, 3, 3, 3, 2, 3, 3, 3, 3, 1, 2, 3, 3, 3, 3, 2, 3, 3, 3, 3, 1, 2, 2, 2, 2, 2, 1, 1, 2, 2, 2, 1, '<endtag>']
# Value in row 2, 'Title' column: Lead Variant
# <LogicalComponent 'Logical System' (896ef2aa-001d-4219-96e8-4a018cae7cfe)>
# .allocated_functions = []
# .applied_property_value_groups = []
# .applied_property_values = []
# .components = []
# .constraints = []
# .description = Markup('')
# .diagrams = []
# .exchanges = []
# .filtering_criteria = []
# .is_abstract = False
# .is_actor = False
# .is_human = False
# .layer = <LogicalArchitecture 'Logical Architecture' (76a4d7e0-803b-40cb-bf5f-91a559ceaae4)>
# .name = 'Logical System'
# .owner = <LogicalComponentPkg 'Structure' (2d9ad464-b546-40eb-929f-f342751868ed)>
# .parent = <LogicalComponentPkg 'Structure' (2d9ad464-b546-40eb-929f-f342751868ed)>
# .parts = ... # backreference to Part - omitted: can be slow to compute
# .physical_links = []
# .physical_paths = []
# .physical_ports = []
# .ports = []
# .progress_status = 'NOT_SET'
# .property_value_groups = []
# .property_value_packages = []
# .property_values = []
# .pvmt = <Property Value Management for <LogicalComponent 'Logical System' (896ef2aa-001d-4219-96e8-4a018cae7cfe)>>
# .realized_components = [0] <SystemComponent 'System' (66b26b78-0a60-4cff-86d5-3fd3419da5e8)>
# .realized_system_components = [0] <SystemComponent 'System' (66b26b78-0a60-4cff-86d5-3fd3419da5e8)>
# .realizing_components = ... # backreference to  - omitted: can be slow to compute
# .realizing_physical_components = ... # backreference to PhysicalComponent - omitted: can be slow to compute
# .related_exchanges = ... # backreference to ComponentExchange - omitted: can be slow to compute
# .requirements = []
# .sid = ''
# .state_machines = []
# .summary = ''
# .traces = []
# .uuid = '896ef2aa-001d-4219-96e8-4a018cae7cfe'
# .validation = <capellambse.extensions.validation._validate.ElementValidation object at 0x7f578efcc2d0>
# .visible_on_diagrams = []
# .xtype = 'org.polarsys.capella.core.data.la:LogicalComponent'
# Current row pointer has been reset to the first row.
#
# Entering cl 0
# Ground Vehicle System      rcl: 0
# Ground Vehicle System      rcl: 0
# row: {'Tc_Level': 0, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Ground Vehicle System     '}
# last_row False
# Ground Vehicle System      rcl: 0
# Ground Vehicle System      rcl: 0
# current row : Ground Vehicle System      rcl: 0 cl: 0
# Ground Vehicle System      rcl: 0
# Ground Vehicle System      rcl: 0
# Ground Vehicle System      rcl: 0
# Ground Vehicle System      rcl: 0
# created : Ground Vehicle System
#
# Family of Vehicles    rcl: 1
# Family of Vehicles    rcl: 1
# row: {'Tc_Level': 1, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Family of Vehicles   '}
# last_row False
# Family of Vehicles    rcl: 1
# Family of Vehicles    rcl: 1
# current row : Family of Vehicles    rcl: 1 cl: 0
# Family of Vehicles    rcl: 1
# Family of Vehicles    rcl: 1
#
# Entering cl 1
# Family of Vehicles    rcl: 1
# Family of Vehicles    rcl: 1
# row: {'Tc_Level': 1, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Family of Vehicles   '}
# last_row False
# Family of Vehicles    rcl: 1
# Family of Vehicles    rcl: 1
# current row : Family of Vehicles    rcl: 1 cl: 1
# Family of Vehicles    rcl: 1
# Family of Vehicles    rcl: 1
# Family of Vehicles    rcl: 1
# Family of Vehicles    rcl: 1
# created : Family of Vehicles
#
# Lead Variant    rcl: 2
# Lead Variant    rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Lead Variant   '}
# last_row False
# Lead Variant    rcl: 2
# Lead Variant    rcl: 2
# current row : Lead Variant    rcl: 2 cl: 1
# Lead Variant    rcl: 2
# Lead Variant    rcl: 2
#
# Entering cl 2
# Lead Variant    rcl: 2
# Lead Variant    rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Lead Variant   '}
# last_row False
# Lead Variant    rcl: 2
# Lead Variant    rcl: 2
# current row : Lead Variant    rcl: 2 cl: 2
# Lead Variant    rcl: 2
# Lead Variant    rcl: 2
# Lead Variant    rcl: 2
# Lead Variant    rcl: 2
# created : Lead Variant
#
# Lead Variant Integration, Assembly, Test, and Checkout  rcl: 3
# Lead Variant Integration, Assembly, Test, and Checkout  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Lead Variant Integration, Assembly, Test, and Checkout '}
# last_row False
# Lead Variant Integration, Assembly, Test, and Checkout  rcl: 3
# Lead Variant Integration, Assembly, Test, and Checkout  rcl: 3
# current row : Lead Variant Integration, Assembly, Test, and Checkout  rcl: 3 cl: 2
# Lead Variant Integration, Assembly, Test, and Checkout  rcl: 3
# Lead Variant Integration, Assembly, Test, and Checkout  rcl: 3
#
# Entering cl 3
# Lead Variant Integration, Assembly, Test, and Checkout  rcl: 3
# Lead Variant Integration, Assembly, Test, and Checkout  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Lead Variant Integration, Assembly, Test, and Checkout '}
# last_row False
# Lead Variant Integration, Assembly, Test, and Checkout  rcl: 3
# Lead Variant Integration, Assembly, Test, and Checkout  rcl: 3
# current row : Lead Variant Integration, Assembly, Test, and Checkout  rcl: 3 cl: 3
# Lead Variant Integration, Assembly, Test, and Checkout  rcl: 3
# Lead Variant Integration, Assembly, Test, and Checkout  rcl: 3
# Lead Variant Integration, Assembly, Test, and Checkout  rcl: 3
# Lead Variant Integration, Assembly, Test, and Checkout  rcl: 3
# created : Lead Variant Integration, Assembly, Test, and Checkout
#
# Hull/Frame/Body/Cab  rcl: 3
# Hull/Frame/Body/Cab  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Hull/Frame/Body/Cab '}
# last_row False
# Hull/Frame/Body/Cab  rcl: 3
# Hull/Frame/Body/Cab  rcl: 3
# current row : Hull/Frame/Body/Cab  rcl: 3 cl: 3
# Hull/Frame/Body/Cab  rcl: 3
# Hull/Frame/Body/Cab  rcl: 3
# Hull/Frame/Body/Cab  rcl: 3
# Hull/Frame/Body/Cab  rcl: 3
# created : Hull/Frame/Body/Cab
#
# System Survivability  rcl: 3
# System Survivability  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'System Survivability '}
# last_row False
# System Survivability  rcl: 3
# System Survivability  rcl: 3
# current row : System Survivability  rcl: 3 cl: 3
# System Survivability  rcl: 3
# System Survivability  rcl: 3
# System Survivability  rcl: 3
# System Survivability  rcl: 3
# created : System Survivability
#
# Turret Assembly  rcl: 3
# Turret Assembly  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Turret Assembly '}
# last_row False
# Turret Assembly  rcl: 3
# Turret Assembly  rcl: 3
# current row : Turret Assembly  rcl: 3 cl: 3
# Turret Assembly  rcl: 3
# Turret Assembly  rcl: 3
# Turret Assembly  rcl: 3
# Turret Assembly  rcl: 3
# created : Turret Assembly
#
# Suspension/Steering  rcl: 3
# Suspension/Steering  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Suspension/Steering '}
# last_row False
# Suspension/Steering  rcl: 3
# Suspension/Steering  rcl: 3
# current row : Suspension/Steering  rcl: 3 cl: 3
# Suspension/Steering  rcl: 3
# Suspension/Steering  rcl: 3
# Suspension/Steering  rcl: 3
# Suspension/Steering  rcl: 3
# created : Suspension/Steering
#
# Vehicle Electronics  rcl: 3
# Vehicle Electronics  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Vehicle Electronics '}
# last_row False
# Vehicle Electronics  rcl: 3
# Vehicle Electronics  rcl: 3
# current row : Vehicle Electronics  rcl: 3 cl: 3
# Vehicle Electronics  rcl: 3
# Vehicle Electronics  rcl: 3
# Vehicle Electronics  rcl: 3
# Vehicle Electronics  rcl: 3
# created : Vehicle Electronics
#
# Power Package/Drive Train  rcl: 3
# Power Package/Drive Train  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Power Package/Drive Train '}
# last_row False
# Power Package/Drive Train  rcl: 3
# Power Package/Drive Train  rcl: 3
# current row : Power Package/Drive Train  rcl: 3 cl: 3
# Power Package/Drive Train  rcl: 3
# Power Package/Drive Train  rcl: 3
# Power Package/Drive Train  rcl: 3
# Power Package/Drive Train  rcl: 3
# created : Power Package/Drive Train
#
# Auxiliary Automotive  rcl: 3
# Auxiliary Automotive  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Auxiliary Automotive '}
# last_row False
# Auxiliary Automotive  rcl: 3
# Auxiliary Automotive  rcl: 3
# current row : Auxiliary Automotive  rcl: 3 cl: 3
# Auxiliary Automotive  rcl: 3
# Auxiliary Automotive  rcl: 3
# Auxiliary Automotive  rcl: 3
# Auxiliary Automotive  rcl: 3
# created : Auxiliary Automotive
#
# Fire Control  rcl: 3
# Fire Control  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Fire Control '}
# last_row False
# Fire Control  rcl: 3
# Fire Control  rcl: 3
# current row : Fire Control  rcl: 3 cl: 3
# Fire Control  rcl: 3
# Fire Control  rcl: 3
# Fire Control  rcl: 3
# Fire Control  rcl: 3
# created : Fire Control
#
# Armament  rcl: 3
# Armament  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Armament '}
# last_row False
# Armament  rcl: 3
# Armament  rcl: 3
# current row : Armament  rcl: 3 cl: 3
# Armament  rcl: 3
# Armament  rcl: 3
# Armament  rcl: 3
# Armament  rcl: 3
# created : Armament
#
# Automatic Ammunition Handling rcl: 3
# Automatic Ammunition Handling rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Automatic Ammunition Handling'}
# last_row False
# Automatic Ammunition Handling rcl: 3
# Automatic Ammunition Handling rcl: 3
# current row : Automatic Ammunition Handling rcl: 3 cl: 3
# Automatic Ammunition Handling rcl: 3
# Automatic Ammunition Handling rcl: 3
# Automatic Ammunition Handling rcl: 3
# Automatic Ammunition Handling rcl: 3
# created : Automatic Ammunition Handling
#
#  Navigation and Remote Piloting Systems rcl: 3
#  Navigation and Remote Piloting Systems rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': ' Navigation and Remote Piloting Systems'}
# last_row False
#  Navigation and Remote Piloting Systems rcl: 3
#  Navigation and Remote Piloting Systems rcl: 3
# current row :  Navigation and Remote Piloting Systems rcl: 3 cl: 3
#  Navigation and Remote Piloting Systems rcl: 3
#  Navigation and Remote Piloting Systems rcl: 3
#  Navigation and Remote Piloting Systems rcl: 3
#  Navigation and Remote Piloting Systems rcl: 3
# created :  Navigation and Remote Piloting Systems
#
# Special Equipment rcl: 3
# Special Equipment rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Special Equipment'}
# last_row False
# Special Equipment rcl: 3
# Special Equipment rcl: 3
# current row : Special Equipment rcl: 3 cl: 3
# Special Equipment rcl: 3
# Special Equipment rcl: 3
# Special Equipment rcl: 3
# Special Equipment rcl: 3
# created : Special Equipment
#
# Communications  rcl: 3
# Communications  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Communications '}
# last_row False
# Communications  rcl: 3
# Communications  rcl: 3
# current row : Communications  rcl: 3 cl: 3
# Communications  rcl: 3
# Communications  rcl: 3
# Communications  rcl: 3
# Communications  rcl: 3
# created : Communications
#
#  Lead Variant Software Release 1...n (Specify)  rcl: 3
#  Lead Variant Software Release 1...n (Specify)  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': ' Lead Variant Software Release 1...n (Specify) '}
# last_row False
#  Lead Variant Software Release 1...n (Specify)  rcl: 3
#  Lead Variant Software Release 1...n (Specify)  rcl: 3
# current row :  Lead Variant Software Release 1...n (Specify)  rcl: 3 cl: 3
#  Lead Variant Software Release 1...n (Specify)  rcl: 3
#  Lead Variant Software Release 1...n (Specify)  rcl: 3
#  Lead Variant Software Release 1...n (Specify)  rcl: 3
#  Lead Variant Software Release 1...n (Specify)  rcl: 3
# created :  Lead Variant Software Release 1...n (Specify)
#
# Other Lead Variant Subsystems 1...n (Specify) rcl: 3
# Other Lead Variant Subsystems 1...n (Specify) rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Other Lead Variant Subsystems 1...n (Specify)'}
# last_row False
# Other Lead Variant Subsystems 1...n (Specify) rcl: 3
# Other Lead Variant Subsystems 1...n (Specify) rcl: 3
# current row : Other Lead Variant Subsystems 1...n (Specify) rcl: 3 cl: 3
# Other Lead Variant Subsystems 1...n (Specify) rcl: 3
# Other Lead Variant Subsystems 1...n (Specify) rcl: 3
# Other Lead Variant Subsystems 1...n (Specify) rcl: 3
# Other Lead Variant Subsystems 1...n (Specify) rcl: 3
# created : Other Lead Variant Subsystems 1...n (Specify)
#
# Variant 2...n (Specify)  rcl: 2
# Exiting 3
# Variant 2...n (Specify)  rcl: 2
#
# Variant 2...n (Specify)  rcl: 2
# Variant 2...n (Specify)  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Variant 2...n (Specify) '}
# last_row False
# Variant 2...n (Specify)  rcl: 2
# Variant 2...n (Specify)  rcl: 2
# current row : Variant 2...n (Specify)  rcl: 2 cl: 2
# Variant 2...n (Specify)  rcl: 2
# Variant 2...n (Specify)  rcl: 2
# Variant 2...n (Specify)  rcl: 2
# Variant 2...n (Specify)  rcl: 2
# created : Variant 2...n (Specify)
#
# Variant Integration, Assembly, Test, and Checkout  rcl: 3
# Variant Integration, Assembly, Test, and Checkout  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Variant Integration, Assembly, Test, and Checkout '}
# last_row False
# Variant Integration, Assembly, Test, and Checkout  rcl: 3
# Variant Integration, Assembly, Test, and Checkout  rcl: 3
# current row : Variant Integration, Assembly, Test, and Checkout  rcl: 3 cl: 2
# Variant Integration, Assembly, Test, and Checkout  rcl: 3
# Variant Integration, Assembly, Test, and Checkout  rcl: 3
#
# Entering cl 3
# Variant Integration, Assembly, Test, and Checkout  rcl: 3
# Variant Integration, Assembly, Test, and Checkout  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Variant Integration, Assembly, Test, and Checkout '}
# last_row False
# Variant Integration, Assembly, Test, and Checkout  rcl: 3
# Variant Integration, Assembly, Test, and Checkout  rcl: 3
# current row : Variant Integration, Assembly, Test, and Checkout  rcl: 3 cl: 3
# Variant Integration, Assembly, Test, and Checkout  rcl: 3
# Variant Integration, Assembly, Test, and Checkout  rcl: 3
# Variant Integration, Assembly, Test, and Checkout  rcl: 3
# Variant Integration, Assembly, Test, and Checkout  rcl: 3
# created : Variant Integration, Assembly, Test, and Checkout
#
# Hull/Frame/Body/Cab  rcl: 3
# Hull/Frame/Body/Cab  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Hull/Frame/Body/Cab '}
# last_row False
# Hull/Frame/Body/Cab  rcl: 3
# Hull/Frame/Body/Cab  rcl: 3
# current row : Hull/Frame/Body/Cab  rcl: 3 cl: 3
# Hull/Frame/Body/Cab  rcl: 3
# Hull/Frame/Body/Cab  rcl: 3
# Hull/Frame/Body/Cab  rcl: 3
# Hull/Frame/Body/Cab  rcl: 3
# created : Hull/Frame/Body/Cab
#
# System Survivability  rcl: 3
# System Survivability  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'System Survivability '}
# last_row False
# System Survivability  rcl: 3
# System Survivability  rcl: 3
# current row : System Survivability  rcl: 3 cl: 3
# System Survivability  rcl: 3
# System Survivability  rcl: 3
# System Survivability  rcl: 3
# System Survivability  rcl: 3
# created : System Survivability
#
# Turret Assembly  rcl: 3
# Turret Assembly  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Turret Assembly '}
# last_row False
# Turret Assembly  rcl: 3
# Turret Assembly  rcl: 3
# current row : Turret Assembly  rcl: 3 cl: 3
# Turret Assembly  rcl: 3
# Turret Assembly  rcl: 3
# Turret Assembly  rcl: 3
# Turret Assembly  rcl: 3
# created : Turret Assembly
#
# Suspension/Steering  rcl: 3
# Suspension/Steering  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Suspension/Steering '}
# last_row False
# Suspension/Steering  rcl: 3
# Suspension/Steering  rcl: 3
# current row : Suspension/Steering  rcl: 3 cl: 3
# Suspension/Steering  rcl: 3
# Suspension/Steering  rcl: 3
# Suspension/Steering  rcl: 3
# Suspension/Steering  rcl: 3
# created : Suspension/Steering
#
# Vehicle Electronics  rcl: 3
# Vehicle Electronics  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Vehicle Electronics '}
# last_row False
# Vehicle Electronics  rcl: 3
# Vehicle Electronics  rcl: 3
# current row : Vehicle Electronics  rcl: 3 cl: 3
# Vehicle Electronics  rcl: 3
# Vehicle Electronics  rcl: 3
# Vehicle Electronics  rcl: 3
# Vehicle Electronics  rcl: 3
# created : Vehicle Electronics
#
# Power Package/Drive Train  rcl: 3
# Power Package/Drive Train  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Power Package/Drive Train '}
# last_row False
# Power Package/Drive Train  rcl: 3
# Power Package/Drive Train  rcl: 3
# current row : Power Package/Drive Train  rcl: 3 cl: 3
# Power Package/Drive Train  rcl: 3
# Power Package/Drive Train  rcl: 3
# Power Package/Drive Train  rcl: 3
# Power Package/Drive Train  rcl: 3
# created : Power Package/Drive Train
#
# Auxiliary Automotive  rcl: 3
# Auxiliary Automotive  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Auxiliary Automotive '}
# last_row False
# Auxiliary Automotive  rcl: 3
# Auxiliary Automotive  rcl: 3
# current row : Auxiliary Automotive  rcl: 3 cl: 3
# Auxiliary Automotive  rcl: 3
# Auxiliary Automotive  rcl: 3
# Auxiliary Automotive  rcl: 3
# Auxiliary Automotive  rcl: 3
# created : Auxiliary Automotive
#
# Fire Control  rcl: 3
# Fire Control  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Fire Control '}
# last_row False
# Fire Control  rcl: 3
# Fire Control  rcl: 3
# current row : Fire Control  rcl: 3 cl: 3
# Fire Control  rcl: 3
# Fire Control  rcl: 3
# Fire Control  rcl: 3
# Fire Control  rcl: 3
# created : Fire Control
#
# Armament  rcl: 3
# Armament  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Armament '}
# last_row False
# Armament  rcl: 3
# Armament  rcl: 3
# current row : Armament  rcl: 3 cl: 3
# Armament  rcl: 3
# Armament  rcl: 3
# Armament  rcl: 3
# Armament  rcl: 3
# created : Armament
#
# Automatic Ammunition Handling  rcl: 3
# Automatic Ammunition Handling  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Automatic Ammunition Handling '}
# last_row False
# Automatic Ammunition Handling  rcl: 3
# Automatic Ammunition Handling  rcl: 3
# current row : Automatic Ammunition Handling  rcl: 3 cl: 3
# Automatic Ammunition Handling  rcl: 3
# Automatic Ammunition Handling  rcl: 3
# Automatic Ammunition Handling  rcl: 3
# Automatic Ammunition Handling  rcl: 3
# created : Automatic Ammunition Handling
#
# Navigation and Remote Piloting Systems rcl: 3
# Navigation and Remote Piloting Systems rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Navigation and Remote Piloting Systems'}
# last_row False
# Navigation and Remote Piloting Systems rcl: 3
# Navigation and Remote Piloting Systems rcl: 3
# current row : Navigation and Remote Piloting Systems rcl: 3 cl: 3
# Navigation and Remote Piloting Systems rcl: 3
# Navigation and Remote Piloting Systems rcl: 3
# Navigation and Remote Piloting Systems rcl: 3
# Navigation and Remote Piloting Systems rcl: 3
# created : Navigation and Remote Piloting Systems
#
# Special Equipment  rcl: 3
# Special Equipment  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Special Equipment '}
# last_row False
# Special Equipment  rcl: 3
# Special Equipment  rcl: 3
# current row : Special Equipment  rcl: 3 cl: 3
# Special Equipment  rcl: 3
# Special Equipment  rcl: 3
# Special Equipment  rcl: 3
# Special Equipment  rcl: 3
# created : Special Equipment
#
# Communications rcl: 3
# Communications rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Communications'}
# last_row False
# Communications rcl: 3
# Communications rcl: 3
# current row : Communications rcl: 3 cl: 3
# Communications rcl: 3
# Communications rcl: 3
# Communications rcl: 3
# Communications rcl: 3
# created : Communications
#
# Variant Software Release 1...n (Specify)  rcl: 3
# Variant Software Release 1...n (Specify)  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Variant Software Release 1...n (Specify) '}
# last_row False
# Variant Software Release 1...n (Specify)  rcl: 3
# Variant Software Release 1...n (Specify)  rcl: 3
# current row : Variant Software Release 1...n (Specify)  rcl: 3 cl: 3
# Variant Software Release 1...n (Specify)  rcl: 3
# Variant Software Release 1...n (Specify)  rcl: 3
# Variant Software Release 1...n (Specify)  rcl: 3
# Variant Software Release 1...n (Specify)  rcl: 3
# created : Variant Software Release 1...n (Specify)
#
# Other Variant Subsystems 1...n (Specify)  rcl: 3
# Other Variant Subsystems 1...n (Specify)  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Other Variant Subsystems 1...n (Specify) '}
# last_row False
# Other Variant Subsystems 1...n (Specify)  rcl: 3
# Other Variant Subsystems 1...n (Specify)  rcl: 3
# current row : Other Variant Subsystems 1...n (Specify)  rcl: 3 cl: 3
# Other Variant Subsystems 1...n (Specify)  rcl: 3
# Other Variant Subsystems 1...n (Specify)  rcl: 3
# Other Variant Subsystems 1...n (Specify)  rcl: 3
# Other Variant Subsystems 1...n (Specify)  rcl: 3
# created : Other Variant Subsystems 1...n (Specify)
#
# Equipment Kits 1...n (Specify)  rcl: 2
# Exiting 3
# Equipment Kits 1...n (Specify)  rcl: 2
#
# Equipment Kits 1...n (Specify)  rcl: 2
# Equipment Kits 1...n (Specify)  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Equipment Kits 1...n (Specify) '}
# last_row False
# Equipment Kits 1...n (Specify)  rcl: 2
# Equipment Kits 1...n (Specify)  rcl: 2
# current row : Equipment Kits 1...n (Specify)  rcl: 2 cl: 2
# Equipment Kits 1...n (Specify)  rcl: 2
# Equipment Kits 1...n (Specify)  rcl: 2
# Equipment Kits 1...n (Specify)  rcl: 2
# Equipment Kits 1...n (Specify)  rcl: 2
# created : Equipment Kits 1...n (Specify)
#
# Secondary Vehicle ( See Note at G.4.3)  rcl: 1
# Exiting 2
# Secondary Vehicle ( See Note at G.4.3)  rcl: 1
#
# Secondary Vehicle ( See Note at G.4.3)  rcl: 1
# Secondary Vehicle ( See Note at G.4.3)  rcl: 1
# row: {'Tc_Level': 1, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Secondary Vehicle ( See Note at G.4.3) '}
# last_row False
# Secondary Vehicle ( See Note at G.4.3)  rcl: 1
# Secondary Vehicle ( See Note at G.4.3)  rcl: 1
# current row : Secondary Vehicle ( See Note at G.4.3)  rcl: 1 cl: 1
# Secondary Vehicle ( See Note at G.4.3)  rcl: 1
# Secondary Vehicle ( See Note at G.4.3)  rcl: 1
# Secondary Vehicle ( See Note at G.4.3)  rcl: 1
# Secondary Vehicle ( See Note at G.4.3)  rcl: 1
# created : Secondary Vehicle ( See Note at G.4.3)
#
# Systems Engineering   rcl: 1
# Systems Engineering   rcl: 1
# row: {'Tc_Level': 1, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Systems Engineering  '}
# last_row False
# Systems Engineering   rcl: 1
# Systems Engineering   rcl: 1
# current row : Systems Engineering   rcl: 1 cl: 1
# Systems Engineering   rcl: 1
# Systems Engineering   rcl: 1
# Systems Engineering   rcl: 1
# Systems Engineering   rcl: 1
# created : Systems Engineering
#
# Software Systems Engineering  rcl: 2
# Software Systems Engineering  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Software Systems Engineering '}
# last_row False
# Software Systems Engineering  rcl: 2
# Software Systems Engineering  rcl: 2
# current row : Software Systems Engineering  rcl: 2 cl: 1
# Software Systems Engineering  rcl: 2
# Software Systems Engineering  rcl: 2
#
# Entering cl 2
# Software Systems Engineering  rcl: 2
# Software Systems Engineering  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Software Systems Engineering '}
# last_row False
# Software Systems Engineering  rcl: 2
# Software Systems Engineering  rcl: 2
# current row : Software Systems Engineering  rcl: 2 cl: 2
# Software Systems Engineering  rcl: 2
# Software Systems Engineering  rcl: 2
# Software Systems Engineering  rcl: 2
# Software Systems Engineering  rcl: 2
# created : Software Systems Engineering
#
# Integrated Logistics Support (ILS) Systems Engineering  rcl: 2
# Integrated Logistics Support (ILS) Systems Engineering  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Integrated Logistics Support (ILS) Systems Engineering '}
# last_row False
# Integrated Logistics Support (ILS) Systems Engineering  rcl: 2
# Integrated Logistics Support (ILS) Systems Engineering  rcl: 2
# current row : Integrated Logistics Support (ILS) Systems Engineering  rcl: 2 cl: 2
# Integrated Logistics Support (ILS) Systems Engineering  rcl: 2
# Integrated Logistics Support (ILS) Systems Engineering  rcl: 2
# Integrated Logistics Support (ILS) Systems Engineering  rcl: 2
# Integrated Logistics Support (ILS) Systems Engineering  rcl: 2
# created : Integrated Logistics Support (ILS) Systems Engineering
#
# Cybersecurity Systems Engineering  rcl: 2
# Cybersecurity Systems Engineering  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Cybersecurity Systems Engineering '}
# last_row False
# Cybersecurity Systems Engineering  rcl: 2
# Cybersecurity Systems Engineering  rcl: 2
# current row : Cybersecurity Systems Engineering  rcl: 2 cl: 2
# Cybersecurity Systems Engineering  rcl: 2
# Cybersecurity Systems Engineering  rcl: 2
# Cybersecurity Systems Engineering  rcl: 2
# Cybersecurity Systems Engineering  rcl: 2
# created : Cybersecurity Systems Engineering
#
# Core Systems Engineering  rcl: 2
# Core Systems Engineering  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Core Systems Engineering '}
# last_row False
# Core Systems Engineering  rcl: 2
# Core Systems Engineering  rcl: 2
# current row : Core Systems Engineering  rcl: 2 cl: 2
# Core Systems Engineering  rcl: 2
# Core Systems Engineering  rcl: 2
# Core Systems Engineering  rcl: 2
# Core Systems Engineering  rcl: 2
# created : Core Systems Engineering
#
# Other Systems Engineering 1...n (Specify)  rcl: 2
# Other Systems Engineering 1...n (Specify)  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Other Systems Engineering 1...n (Specify) '}
# last_row False
# Other Systems Engineering 1...n (Specify)  rcl: 2
# Other Systems Engineering 1...n (Specify)  rcl: 2
# current row : Other Systems Engineering 1...n (Specify)  rcl: 2 cl: 2
# Other Systems Engineering 1...n (Specify)  rcl: 2
# Other Systems Engineering 1...n (Specify)  rcl: 2
# Other Systems Engineering 1...n (Specify)  rcl: 2
# Other Systems Engineering 1...n (Specify)  rcl: 2
# created : Other Systems Engineering 1...n (Specify)
#
# Program Management    rcl: 1
# Exiting 2
# Program Management    rcl: 1
#
# Program Management    rcl: 1
# Program Management    rcl: 1
# row: {'Tc_Level': 1, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Program Management   '}
# last_row False
# Program Management    rcl: 1
# Program Management    rcl: 1
# current row : Program Management    rcl: 1 cl: 1
# Program Management    rcl: 1
# Program Management    rcl: 1
# Program Management    rcl: 1
# Program Management    rcl: 1
# created : Program Management
#
# Software Program Management  rcl: 2
# Software Program Management  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Software Program Management '}
# last_row False
# Software Program Management  rcl: 2
# Software Program Management  rcl: 2
# current row : Software Program Management  rcl: 2 cl: 1
# Software Program Management  rcl: 2
# Software Program Management  rcl: 2
#
# Entering cl 2
# Software Program Management  rcl: 2
# Software Program Management  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Software Program Management '}
# last_row False
# Software Program Management  rcl: 2
# Software Program Management  rcl: 2
# current row : Software Program Management  rcl: 2 cl: 2
# Software Program Management  rcl: 2
# Software Program Management  rcl: 2
# Software Program Management  rcl: 2
# Software Program Management  rcl: 2
# created : Software Program Management
#
# Integrated Logistics Support (ILS) Program Management  rcl: 2
# Integrated Logistics Support (ILS) Program Management  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Integrated Logistics Support (ILS) Program Management '}
# last_row False
# Integrated Logistics Support (ILS) Program Management  rcl: 2
# Integrated Logistics Support (ILS) Program Management  rcl: 2
# current row : Integrated Logistics Support (ILS) Program Management  rcl: 2 cl: 2
# Integrated Logistics Support (ILS) Program Management  rcl: 2
# Integrated Logistics Support (ILS) Program Management  rcl: 2
# Integrated Logistics Support (ILS) Program Management  rcl: 2
# Integrated Logistics Support (ILS) Program Management  rcl: 2
# created : Integrated Logistics Support (ILS) Program Management
#
# Cybersecurity Management  rcl: 2
# Cybersecurity Management  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Cybersecurity Management '}
# last_row False
# Cybersecurity Management  rcl: 2
# Cybersecurity Management  rcl: 2
# current row : Cybersecurity Management  rcl: 2 cl: 2
# Cybersecurity Management  rcl: 2
# Cybersecurity Management  rcl: 2
# Cybersecurity Management  rcl: 2
# Cybersecurity Management  rcl: 2
# created : Cybersecurity Management
#
# Core Program Management  rcl: 2
# Core Program Management  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Core Program Management '}
# last_row False
# Core Program Management  rcl: 2
# Core Program Management  rcl: 2
# current row : Core Program Management  rcl: 2 cl: 2
# Core Program Management  rcl: 2
# Core Program Management  rcl: 2
# Core Program Management  rcl: 2
# Core Program Management  rcl: 2
# created : Core Program Management
#
# Other Program Management 1...n (Specify)  rcl: 2
# Other Program Management 1...n (Specify)  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Other Program Management 1...n (Specify) '}
# last_row False
# Other Program Management 1...n (Specify)  rcl: 2
# Other Program Management 1...n (Specify)  rcl: 2
# current row : Other Program Management 1...n (Specify)  rcl: 2 cl: 2
# Other Program Management 1...n (Specify)  rcl: 2
# Other Program Management 1...n (Specify)  rcl: 2
# Other Program Management 1...n (Specify)  rcl: 2
# Other Program Management 1...n (Specify)  rcl: 2
# created : Other Program Management 1...n (Specify)
#
# System Test and Evaluation    rcl: 1
# Exiting 2
# System Test and Evaluation    rcl: 1
#
# System Test and Evaluation    rcl: 1
# System Test and Evaluation    rcl: 1
# row: {'Tc_Level': 1, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'System Test and Evaluation   '}
# last_row False
# System Test and Evaluation    rcl: 1
# System Test and Evaluation    rcl: 1
# current row : System Test and Evaluation    rcl: 1 cl: 1
# System Test and Evaluation    rcl: 1
# System Test and Evaluation    rcl: 1
# System Test and Evaluation    rcl: 1
# System Test and Evaluation    rcl: 1
# created : System Test and Evaluation
#
# Developmental Test and Evaluation  rcl: 2
# Developmental Test and Evaluation  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Developmental Test and Evaluation '}
# last_row False
# Developmental Test and Evaluation  rcl: 2
# Developmental Test and Evaluation  rcl: 2
# current row : Developmental Test and Evaluation  rcl: 2 cl: 1
# Developmental Test and Evaluation  rcl: 2
# Developmental Test and Evaluation  rcl: 2
#
# Entering cl 2
# Developmental Test and Evaluation  rcl: 2
# Developmental Test and Evaluation  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Developmental Test and Evaluation '}
# last_row False
# Developmental Test and Evaluation  rcl: 2
# Developmental Test and Evaluation  rcl: 2
# current row : Developmental Test and Evaluation  rcl: 2 cl: 2
# Developmental Test and Evaluation  rcl: 2
# Developmental Test and Evaluation  rcl: 2
# Developmental Test and Evaluation  rcl: 2
# Developmental Test and Evaluation  rcl: 2
# created : Developmental Test and Evaluation
#
# Cybersecurity Test and Evaluation  rcl: 3
# Cybersecurity Test and Evaluation  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Cybersecurity Test and Evaluation '}
# last_row False
# Cybersecurity Test and Evaluation  rcl: 3
# Cybersecurity Test and Evaluation  rcl: 3
# current row : Cybersecurity Test and Evaluation  rcl: 3 cl: 2
# Cybersecurity Test and Evaluation  rcl: 3
# Cybersecurity Test and Evaluation  rcl: 3
#
# Entering cl 3
# Cybersecurity Test and Evaluation  rcl: 3
# Cybersecurity Test and Evaluation  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Cybersecurity Test and Evaluation '}
# last_row False
# Cybersecurity Test and Evaluation  rcl: 3
# Cybersecurity Test and Evaluation  rcl: 3
# current row : Cybersecurity Test and Evaluation  rcl: 3 cl: 3
# Cybersecurity Test and Evaluation  rcl: 3
# Cybersecurity Test and Evaluation  rcl: 3
# Cybersecurity Test and Evaluation  rcl: 3
# Cybersecurity Test and Evaluation  rcl: 3
# created : Cybersecurity Test and Evaluation
#
# Other DT&E Tests 1…n (Specify)  rcl: 3
# Other DT&E Tests 1…n (Specify)  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Other DT&E Tests 1…n (Specify) '}
# last_row False
# Other DT&E Tests 1…n (Specify)  rcl: 3
# Other DT&E Tests 1…n (Specify)  rcl: 3
# current row : Other DT&E Tests 1…n (Specify)  rcl: 3 cl: 3
# Other DT&E Tests 1…n (Specify)  rcl: 3
# Other DT&E Tests 1…n (Specify)  rcl: 3
# Other DT&E Tests 1…n (Specify)  rcl: 3
# Other DT&E Tests 1…n (Specify)  rcl: 3
# created : Other DT&E Tests 1…n (Specify)
#
# Operational Test and Evaluation  rcl: 2
# Exiting 3
# Operational Test and Evaluation  rcl: 2
#
# Operational Test and Evaluation  rcl: 2
# Operational Test and Evaluation  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Operational Test and Evaluation '}
# last_row False
# Operational Test and Evaluation  rcl: 2
# Operational Test and Evaluation  rcl: 2
# current row : Operational Test and Evaluation  rcl: 2 cl: 2
# Operational Test and Evaluation  rcl: 2
# Operational Test and Evaluation  rcl: 2
# Operational Test and Evaluation  rcl: 2
# Operational Test and Evaluation  rcl: 2
# created : Operational Test and Evaluation
#
# Cybersecurity Test and Evaluation  rcl: 3
# Cybersecurity Test and Evaluation  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Cybersecurity Test and Evaluation '}
# last_row False
# Cybersecurity Test and Evaluation  rcl: 3
# Cybersecurity Test and Evaluation  rcl: 3
# current row : Cybersecurity Test and Evaluation  rcl: 3 cl: 2
# Cybersecurity Test and Evaluation  rcl: 3
# Cybersecurity Test and Evaluation  rcl: 3
#
# Entering cl 3
# Cybersecurity Test and Evaluation  rcl: 3
# Cybersecurity Test and Evaluation  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Cybersecurity Test and Evaluation '}
# last_row False
# Cybersecurity Test and Evaluation  rcl: 3
# Cybersecurity Test and Evaluation  rcl: 3
# current row : Cybersecurity Test and Evaluation  rcl: 3 cl: 3
# Cybersecurity Test and Evaluation  rcl: 3
# Cybersecurity Test and Evaluation  rcl: 3
# Cybersecurity Test and Evaluation  rcl: 3
# Cybersecurity Test and Evaluation  rcl: 3
# created : Cybersecurity Test and Evaluation
#
# Other OT&E Tests 1…n (Specify)  rcl: 3
# Other OT&E Tests 1…n (Specify)  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Other OT&E Tests 1…n (Specify) '}
# last_row False
# Other OT&E Tests 1…n (Specify)  rcl: 3
# Other OT&E Tests 1…n (Specify)  rcl: 3
# current row : Other OT&E Tests 1…n (Specify)  rcl: 3 cl: 3
# Other OT&E Tests 1…n (Specify)  rcl: 3
# Other OT&E Tests 1…n (Specify)  rcl: 3
# Other OT&E Tests 1…n (Specify)  rcl: 3
# Other OT&E Tests 1…n (Specify)  rcl: 3
# created : Other OT&E Tests 1…n (Specify)
#
# Live Fire Test and Evaluation  rcl: 2
# Exiting 3
# Live Fire Test and Evaluation  rcl: 2
#
# Live Fire Test and Evaluation  rcl: 2
# Live Fire Test and Evaluation  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Live Fire Test and Evaluation '}
# last_row False
# Live Fire Test and Evaluation  rcl: 2
# Live Fire Test and Evaluation  rcl: 2
# current row : Live Fire Test and Evaluation  rcl: 2 cl: 2
# Live Fire Test and Evaluation  rcl: 2
# Live Fire Test and Evaluation  rcl: 2
# Live Fire Test and Evaluation  rcl: 2
# Live Fire Test and Evaluation  rcl: 2
# created : Live Fire Test and Evaluation
#
# Mock-ups/System Integration Labs (SILs)  rcl: 2
# Mock-ups/System Integration Labs (SILs)  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Mock-ups/System Integration Labs (SILs) '}
# last_row False
# Mock-ups/System Integration Labs (SILs)  rcl: 2
# Mock-ups/System Integration Labs (SILs)  rcl: 2
# current row : Mock-ups/System Integration Labs (SILs)  rcl: 2 cl: 2
# Mock-ups/System Integration Labs (SILs)  rcl: 2
# Mock-ups/System Integration Labs (SILs)  rcl: 2
# Mock-ups/System Integration Labs (SILs)  rcl: 2
# Mock-ups/System Integration Labs (SILs)  rcl: 2
# created : Mock-ups/System Integration Labs (SILs)
#
# Test and Evaluation Support  rcl: 2
# Test and Evaluation Support  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Test and Evaluation Support '}
# last_row False
# Test and Evaluation Support  rcl: 2
# Test and Evaluation Support  rcl: 2
# current row : Test and Evaluation Support  rcl: 2 cl: 2
# Test and Evaluation Support  rcl: 2
# Test and Evaluation Support  rcl: 2
# Test and Evaluation Support  rcl: 2
# Test and Evaluation Support  rcl: 2
# created : Test and Evaluation Support
#
# Test Facilities  rcl: 2
# Test Facilities  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Test Facilities '}
# last_row False
# Test Facilities  rcl: 2
# Test Facilities  rcl: 2
# current row : Test Facilities  rcl: 2 cl: 2
# Test Facilities  rcl: 2
# Test Facilities  rcl: 2
# Test Facilities  rcl: 2
# Test Facilities  rcl: 2
# created : Test Facilities
#
# Training  rcl: 1
# Exiting 2
# Training  rcl: 1
#
# Training  rcl: 1
# Training  rcl: 1
# row: {'Tc_Level': 1, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Training '}
# last_row False
# Training  rcl: 1
# Training  rcl: 1
# current row : Training  rcl: 1 cl: 1
# Training  rcl: 1
# Training  rcl: 1
# Training  rcl: 1
# Training  rcl: 1
# created : Training
#
# Equipment  rcl: 2
# Equipment  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Equipment '}
# last_row False
# Equipment  rcl: 2
# Equipment  rcl: 2
# current row : Equipment  rcl: 2 cl: 1
# Equipment  rcl: 2
# Equipment  rcl: 2
#
# Entering cl 2
# Equipment  rcl: 2
# Equipment  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Equipment '}
# last_row False
# Equipment  rcl: 2
# Equipment  rcl: 2
# current row : Equipment  rcl: 2 cl: 2
# Equipment  rcl: 2
# Equipment  rcl: 2
# Equipment  rcl: 2
# Equipment  rcl: 2
# created : Equipment
#
# Operator Instructional Equipment  rcl: 3
# Operator Instructional Equipment  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Operator Instructional Equipment '}
# last_row False
# Operator Instructional Equipment  rcl: 3
# Operator Instructional Equipment  rcl: 3
# current row : Operator Instructional Equipment  rcl: 3 cl: 2
# Operator Instructional Equipment  rcl: 3
# Operator Instructional Equipment  rcl: 3
#
# Entering cl 3
# Operator Instructional Equipment  rcl: 3
# Operator Instructional Equipment  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Operator Instructional Equipment '}
# last_row False
# Operator Instructional Equipment  rcl: 3
# Operator Instructional Equipment  rcl: 3
# current row : Operator Instructional Equipment  rcl: 3 cl: 3
# Operator Instructional Equipment  rcl: 3
# Operator Instructional Equipment  rcl: 3
# Operator Instructional Equipment  rcl: 3
# Operator Instructional Equipment  rcl: 3
# created : Operator Instructional Equipment
#
# Maintainer Instructional Equipment  rcl: 3
# Maintainer Instructional Equipment  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Maintainer Instructional Equipment '}
# last_row False
# Maintainer Instructional Equipment  rcl: 3
# Maintainer Instructional Equipment  rcl: 3
# current row : Maintainer Instructional Equipment  rcl: 3 cl: 3
# Maintainer Instructional Equipment  rcl: 3
# Maintainer Instructional Equipment  rcl: 3
# Maintainer Instructional Equipment  rcl: 3
# Maintainer Instructional Equipment  rcl: 3
# created : Maintainer Instructional Equipment
#
# Services  rcl: 2
# Exiting 3
# Services  rcl: 2
#
# Services  rcl: 2
# Services  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Services '}
# last_row False
# Services  rcl: 2
# Services  rcl: 2
# current row : Services  rcl: 2 cl: 2
# Services  rcl: 2
# Services  rcl: 2
# Services  rcl: 2
# Services  rcl: 2
# created : Services
#
# Operator Instructional Services  rcl: 3
# Operator Instructional Services  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Operator Instructional Services '}
# last_row False
# Operator Instructional Services  rcl: 3
# Operator Instructional Services  rcl: 3
# current row : Operator Instructional Services  rcl: 3 cl: 2
# Operator Instructional Services  rcl: 3
# Operator Instructional Services  rcl: 3
#
# Entering cl 3
# Operator Instructional Services  rcl: 3
# Operator Instructional Services  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Operator Instructional Services '}
# last_row False
# Operator Instructional Services  rcl: 3
# Operator Instructional Services  rcl: 3
# current row : Operator Instructional Services  rcl: 3 cl: 3
# Operator Instructional Services  rcl: 3
# Operator Instructional Services  rcl: 3
# Operator Instructional Services  rcl: 3
# Operator Instructional Services  rcl: 3
# created : Operator Instructional Services
#
# Maintainer Instructional Services  rcl: 3
# Maintainer Instructional Services  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Maintainer Instructional Services '}
# last_row False
# Maintainer Instructional Services  rcl: 3
# Maintainer Instructional Services  rcl: 3
# current row : Maintainer Instructional Services  rcl: 3 cl: 3
# Maintainer Instructional Services  rcl: 3
# Maintainer Instructional Services  rcl: 3
# Maintainer Instructional Services  rcl: 3
# Maintainer Instructional Services  rcl: 3
# created : Maintainer Instructional Services
#
# Facilities   rcl: 2
# Exiting 3
# Facilities   rcl: 2
#
# Facilities   rcl: 2
# Facilities   rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Facilities  '}
# last_row False
# Facilities   rcl: 2
# Facilities   rcl: 2
# current row : Facilities   rcl: 2 cl: 2
# Facilities   rcl: 2
# Facilities   rcl: 2
# Facilities   rcl: 2
# Facilities   rcl: 2
# created : Facilities
#
# Training Software 1...n (Specify)  rcl: 2
# Training Software 1...n (Specify)  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Training Software 1...n (Specify) '}
# last_row False
# Training Software 1...n (Specify)  rcl: 2
# Training Software 1...n (Specify)  rcl: 2
# current row : Training Software 1...n (Specify)  rcl: 2 cl: 2
# Training Software 1...n (Specify)  rcl: 2
# Training Software 1...n (Specify)  rcl: 2
# Training Software 1...n (Specify)  rcl: 2
# Training Software 1...n (Specify)  rcl: 2
# created : Training Software 1...n (Specify)
#
# Data  rcl: 1
# Exiting 2
# Data  rcl: 1
#
# Data  rcl: 1
# Data  rcl: 1
# row: {'Tc_Level': 1, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Data '}
# last_row False
# Data  rcl: 1
# Data  rcl: 1
# current row : Data  rcl: 1 cl: 1
# Data  rcl: 1
# Data  rcl: 1
# Data  rcl: 1
# Data  rcl: 1
# created : Data
#
# Data Deliverables 1...n (Specify)  rcl: 2
# Data Deliverables 1...n (Specify)  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Data Deliverables 1...n (Specify) '}
# last_row False
# Data Deliverables 1...n (Specify)  rcl: 2
# Data Deliverables 1...n (Specify)  rcl: 2
# current row : Data Deliverables 1...n (Specify)  rcl: 2 cl: 1
# Data Deliverables 1...n (Specify)  rcl: 2
# Data Deliverables 1...n (Specify)  rcl: 2
#
# Entering cl 2
# Data Deliverables 1...n (Specify)  rcl: 2
# Data Deliverables 1...n (Specify)  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Data Deliverables 1...n (Specify) '}
# last_row False
# Data Deliverables 1...n (Specify)  rcl: 2
# Data Deliverables 1...n (Specify)  rcl: 2
# current row : Data Deliverables 1...n (Specify)  rcl: 2 cl: 2
# Data Deliverables 1...n (Specify)  rcl: 2
# Data Deliverables 1...n (Specify)  rcl: 2
# Data Deliverables 1...n (Specify)  rcl: 2
# Data Deliverables 1...n (Specify)  rcl: 2
# created : Data Deliverables 1...n (Specify)
#
# Data Repository  rcl: 2
# Data Repository  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Data Repository '}
# last_row False
# Data Repository  rcl: 2
# Data Repository  rcl: 2
# current row : Data Repository  rcl: 2 cl: 2
# Data Repository  rcl: 2
# Data Repository  rcl: 2
# Data Repository  rcl: 2
# Data Repository  rcl: 2
# created : Data Repository
#
# Data Rights 1...n (Specify)  rcl: 2
# Data Rights 1...n (Specify)  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Data Rights 1...n (Specify) '}
# last_row False
# Data Rights 1...n (Specify)  rcl: 2
# Data Rights 1...n (Specify)  rcl: 2
# current row : Data Rights 1...n (Specify)  rcl: 2 cl: 2
# Data Rights 1...n (Specify)  rcl: 2
# Data Rights 1...n (Specify)  rcl: 2
# Data Rights 1...n (Specify)  rcl: 2
# Data Rights 1...n (Specify)  rcl: 2
# created : Data Rights 1...n (Specify)
#
# Peculiar Support Equipment  rcl: 1
# Exiting 2
# Peculiar Support Equipment  rcl: 1
#
# Peculiar Support Equipment  rcl: 1
# Peculiar Support Equipment  rcl: 1
# row: {'Tc_Level': 1, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Peculiar Support Equipment '}
# last_row False
# Peculiar Support Equipment  rcl: 1
# Peculiar Support Equipment  rcl: 1
# current row : Peculiar Support Equipment  rcl: 1 cl: 1
# Peculiar Support Equipment  rcl: 1
# Peculiar Support Equipment  rcl: 1
# Peculiar Support Equipment  rcl: 1
# Peculiar Support Equipment  rcl: 1
# created : Peculiar Support Equipment
#
# Test and Measurement Equipment  rcl: 2
# Test and Measurement Equipment  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Test and Measurement Equipment '}
# last_row False
# Test and Measurement Equipment  rcl: 2
# Test and Measurement Equipment  rcl: 2
# current row : Test and Measurement Equipment  rcl: 2 cl: 1
# Test and Measurement Equipment  rcl: 2
# Test and Measurement Equipment  rcl: 2
#
# Entering cl 2
# Test and Measurement Equipment  rcl: 2
# Test and Measurement Equipment  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Test and Measurement Equipment '}
# last_row False
# Test and Measurement Equipment  rcl: 2
# Test and Measurement Equipment  rcl: 2
# current row : Test and Measurement Equipment  rcl: 2 cl: 2
# Test and Measurement Equipment  rcl: 2
# Test and Measurement Equipment  rcl: 2
# Test and Measurement Equipment  rcl: 2
# Test and Measurement Equipment  rcl: 2
# created : Test and Measurement Equipment
#
# Test and Measurement Equipment (Airframe/Hull/Vehicle)  rcl: 3
# Test and Measurement Equipment (Airframe/Hull/Vehicle)  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Test and Measurement Equipment (Airframe/Hull/Vehicle) '}
# last_row False
# Test and Measurement Equipment (Airframe/Hull/Vehicle)  rcl: 3
# Test and Measurement Equipment (Airframe/Hull/Vehicle)  rcl: 3
# current row : Test and Measurement Equipment (Airframe/Hull/Vehicle)  rcl: 3 cl: 2
# Test and Measurement Equipment (Airframe/Hull/Vehicle)  rcl: 3
# Test and Measurement Equipment (Airframe/Hull/Vehicle)  rcl: 3
#
# Entering cl 3
# Test and Measurement Equipment (Airframe/Hull/Vehicle)  rcl: 3
# Test and Measurement Equipment (Airframe/Hull/Vehicle)  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Test and Measurement Equipment (Airframe/Hull/Vehicle) '}
# last_row False
# Test and Measurement Equipment (Airframe/Hull/Vehicle)  rcl: 3
# Test and Measurement Equipment (Airframe/Hull/Vehicle)  rcl: 3
# current row : Test and Measurement Equipment (Airframe/Hull/Vehicle)  rcl: 3 cl: 3
# Test and Measurement Equipment (Airframe/Hull/Vehicle)  rcl: 3
# Test and Measurement Equipment (Airframe/Hull/Vehicle)  rcl: 3
# Test and Measurement Equipment (Airframe/Hull/Vehicle)  rcl: 3
# Test and Measurement Equipment (Airframe/Hull/Vehicle)  rcl: 3
# created : Test and Measurement Equipment (Airframe/Hull/Vehicle)
#
# Test and Measurement Equipment (Propulsion)  rcl: 3
# ...
# Test and Measurement Equipment (Propulsion)  rcl: 3
# Test and Measurement Equipment (Propulsion)  rcl: 3
# Test and Measurement Equipment (Propulsion)  rcl: 3
# Test and Measurement Equipment (Propulsion)  rcl: 3
# created : Test and Measurement Equipment (Propulsion)
#
# Test and Measurement Equipment (Electronics/Avionics)  rcl: 3
# Test and Measurement Equipment (Electronics/Avionics)  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Test and Measurement Equipment (Electronics/Avionics) '}
# last_row False
# Test and Measurement Equipment (Electronics/Avionics)  rcl: 3
# Test and Measurement Equipment (Electronics/Avionics)  rcl: 3
# current row : Test and Measurement Equipment (Electronics/Avionics)  rcl: 3 cl: 3
# Test and Measurement Equipment (Electronics/Avionics)  rcl: 3
# Test and Measurement Equipment (Electronics/Avionics)  rcl: 3
# Test and Measurement Equipment (Electronics/Avionics)  rcl: 3
# Test and Measurement Equipment (Electronics/Avionics)  rcl: 3
# created : Test and Measurement Equipment (Electronics/Avionics)
#
# Test and Measurement Equipment (Other Major Subsystems 1...n (Specify))  rcl: 3
# Test and Measurement Equipment (Other Major Subsystems 1...n (Specify))  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Test and Measurement Equipment (Other Major Subsystems 1...n (Specify)) '}
# last_row False
# Test and Measurement Equipment (Other Major Subsystems 1...n (Specify))  rcl: 3
# Test and Measurement Equipment (Other Major Subsystems 1...n (Specify))  rcl: 3
# current row : Test and Measurement Equipment (Other Major Subsystems 1...n (Specify))  rcl: 3 cl: 3
# Test and Measurement Equipment (Other Major Subsystems 1...n (Specify))  rcl: 3
# Test and Measurement Equipment (Other Major Subsystems 1...n (Specify))  rcl: 3
# Test and Measurement Equipment (Other Major Subsystems 1...n (Specify))  rcl: 3
# Test and Measurement Equipment (Other Major Subsystems 1...n (Specify))  rcl: 3
# created : Test and Measurement Equipment (Other Major Subsystems 1...n (Specify))
#
# Support and Handling Equipment  rcl: 2
# Exiting 3
# Support and Handling Equipment  rcl: 2
#
# Support and Handling Equipment  rcl: 2
# Support and Handling Equipment  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Support and Handling Equipment '}
# last_row False
# Support and Handling Equipment  rcl: 2
# Support and Handling Equipment  rcl: 2
# current row : Support and Handling Equipment  rcl: 2 cl: 2
# Support and Handling Equipment  rcl: 2
# Support and Handling Equipment  rcl: 2
# Support and Handling Equipment  rcl: 2
# Support and Handling Equipment  rcl: 2
# created : Support and Handling Equipment
#
# Support and Handling Equipment (Airframe/Hull/Vehicle)  rcl: 3
# Support and Handling Equipment (Airframe/Hull/Vehicle)  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Support and Handling Equipment (Airframe/Hull/Vehicle) '}
# last_row False
# Support and Handling Equipment (Airframe/Hull/Vehicle)  rcl: 3
# Support and Handling Equipment (Airframe/Hull/Vehicle)  rcl: 3
# current row : Support and Handling Equipment (Airframe/Hull/Vehicle)  rcl: 3 cl: 2
# Support and Handling Equipment (Airframe/Hull/Vehicle)  rcl: 3
# Support and Handling Equipment (Airframe/Hull/Vehicle)  rcl: 3
#
# Entering cl 3
# Support and Handling Equipment (Airframe/Hull/Vehicle)  rcl: 3
# Support and Handling Equipment (Airframe/Hull/Vehicle)  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Support and Handling Equipment (Airframe/Hull/Vehicle) '}
# last_row False
# Support and Handling Equipment (Airframe/Hull/Vehicle)  rcl: 3
# Support and Handling Equipment (Airframe/Hull/Vehicle)  rcl: 3
# current row : Support and Handling Equipment (Airframe/Hull/Vehicle)  rcl: 3 cl: 3
# Support and Handling Equipment (Airframe/Hull/Vehicle)  rcl: 3
# Support and Handling Equipment (Airframe/Hull/Vehicle)  rcl: 3
# Support and Handling Equipment (Airframe/Hull/Vehicle)  rcl: 3
# Support and Handling Equipment (Airframe/Hull/Vehicle)  rcl: 3
# created : Support and Handling Equipment (Airframe/Hull/Vehicle)
#
# Support and Handling Equipment (Propulsion)  rcl: 3
# Support and Handling Equipment (Propulsion)  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Support and Handling Equipment (Propulsion) '}
# last_row False
# Support and Handling Equipment (Propulsion)  rcl: 3
# Support and Handling Equipment (Propulsion)  rcl: 3
# current row : Support and Handling Equipment (Propulsion)  rcl: 3 cl: 3
# Support and Handling Equipment (Propulsion)  rcl: 3
# Support and Handling Equipment (Propulsion)  rcl: 3
# Support and Handling Equipment (Propulsion)  rcl: 3
# Support and Handling Equipment (Propulsion)  rcl: 3
# created : Support and Handling Equipment (Propulsion)
#
# Support and Handling Equipment (Electronics/Avionics)  rcl: 3
# Support and Handling Equipment (Electronics/Avionics)  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Support and Handling Equipment (Electronics/Avionics) '}
# last_row False
# Support and Handling Equipment (Electronics/Avionics)  rcl: 3
# Support and Handling Equipment (Electronics/Avionics)  rcl: 3
# current row : Support and Handling Equipment (Electronics/Avionics)  rcl: 3 cl: 3
# Support and Handling Equipment (Electronics/Avionics)  rcl: 3
# Support and Handling Equipment (Electronics/Avionics)  rcl: 3
# Support and Handling Equipment (Electronics/Avionics)  rcl: 3
# Support and Handling Equipment (Electronics/Avionics)  rcl: 3
# created : Support and Handling Equipment (Electronics/Avionics)
#
# Support and Handling Equipment (Other Major Subsystems 1...n (Specify))  rcl: 3
# Support and Handling Equipment (Other Major Subsystems 1...n (Specify))  rcl: 3
# row: {'Tc_Level': 3, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Support and Handling Equipment (Other Major Subsystems 1...n (Specify)) '}
# last_row False
# Support and Handling Equipment (Other Major Subsystems 1...n (Specify))  rcl: 3
# Support and Handling Equipment (Other Major Subsystems 1...n (Specify))  rcl: 3
# current row : Support and Handling Equipment (Other Major Subsystems 1...n (Specify))  rcl: 3 cl: 3
# Support and Handling Equipment (Other Major Subsystems 1...n (Specify))  rcl: 3
# Support and Handling Equipment (Other Major Subsystems 1...n (Specify))  rcl: 3
# Support and Handling Equipment (Other Major Subsystems 1...n (Specify))  rcl: 3
# Support and Handling Equipment (Other Major Subsystems 1...n (Specify))  rcl: 3
# created : Support and Handling Equipment (Other Major Subsystems 1...n (Specify))
#
# Operational/Site Activation by Site 1...n (Specify)  rcl: 1
# Exiting 3
# Operational/Site Activation by Site 1...n (Specify)  rcl: 1
#
# Operational/Site Activation by Site 1...n (Specify)  rcl: 1
# Operational/Site Activation by Site 1...n (Specify)  rcl: 1
# row: {'Tc_Level': 1, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Operational/Site Activation by Site 1...n (Specify) '}
# last_row False
# Operational/Site Activation by Site 1...n (Specify)  rcl: 1
# Operational/Site Activation by Site 1...n (Specify)  rcl: 1
# current row : Operational/Site Activation by Site 1...n (Specify)  rcl: 1 cl: 1
# Operational/Site Activation by Site 1...n (Specify)  rcl: 1
# Operational/Site Activation by Site 1...n (Specify)  rcl: 1
# Operational/Site Activation by Site 1...n (Specify)  rcl: 1
# Operational/Site Activation by Site 1...n (Specify)  rcl: 1
# created : Operational/Site Activation by Site 1...n (Specify)
#
# System Assembly, Installation, and Checkout  rcl: 2
# System Assembly, Installation, and Checkout  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'System Assembly, Installation, and Checkout '}
# last_row False
# System Assembly, Installation, and Checkout  rcl: 2
# System Assembly, Installation, and Checkout  rcl: 2
# current row : System Assembly, Installation, and Checkout  rcl: 2 cl: 1
# System Assembly, Installation, and Checkout  rcl: 2
# System Assembly, Installation, and Checkout  rcl: 2
#
# Entering cl 2
# System Assembly, Installation, and Checkout  rcl: 2
# System Assembly, Installation, and Checkout  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'System Assembly, Installation, and Checkout '}
# last_row False
# System Assembly, Installation, and Checkout  rcl: 2
# System Assembly, Installation, and Checkout  rcl: 2
# current row : System Assembly, Installation, and Checkout  rcl: 2 cl: 2
# System Assembly, Installation, and Checkout  rcl: 2
# System Assembly, Installation, and Checkout  rcl: 2
# System Assembly, Installation, and Checkout  rcl: 2
# System Assembly, Installation, and Checkout  rcl: 2
# created : System Assembly, Installation, and Checkout
#
# Contractor Technical Support  rcl: 2
# Contractor Technical Support  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Contractor Technical Support '}
# last_row False
# Contractor Technical Support  rcl: 2
# Contractor Technical Support  rcl: 2
# current row : Contractor Technical Support  rcl: 2 cl: 2
# Contractor Technical Support  rcl: 2
# Contractor Technical Support  rcl: 2
# Contractor Technical Support  rcl: 2
# Contractor Technical Support  rcl: 2
# created : Contractor Technical Support
#
# Site Construction  rcl: 2
# Site Construction  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Site Construction '}
# last_row False
# Site Construction  rcl: 2
# Site Construction  rcl: 2
# current row : Site Construction  rcl: 2 cl: 2
# Site Construction  rcl: 2
# Site Construction  rcl: 2
# Site Construction  rcl: 2
# Site Construction  rcl: 2
# created : Site Construction
#
# Site/Ship/Vehicle Conversion  rcl: 2
# Site/Ship/Vehicle Conversion  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Site/Ship/Vehicle Conversion '}
# last_row False
# Site/Ship/Vehicle Conversion  rcl: 2
# Site/Ship/Vehicle Conversion  rcl: 2
# current row : Site/Ship/Vehicle Conversion  rcl: 2 cl: 2
# Site/Ship/Vehicle Conversion  rcl: 2
# Site/Ship/Vehicle Conversion  rcl: 2
# Site/Ship/Vehicle Conversion  rcl: 2
# Site/Ship/Vehicle Conversion  rcl: 2
# created : Site/Ship/Vehicle Conversion
#
# Interim Contractor Support  rcl: 2
# Interim Contractor Support  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Interim Contractor Support '}
# last_row False
# Interim Contractor Support  rcl: 2
# Interim Contractor Support  rcl: 2
# current row : Interim Contractor Support  rcl: 2 cl: 2
# Interim Contractor Support  rcl: 2
# Interim Contractor Support  rcl: 2
# Interim Contractor Support  rcl: 2
# Interim Contractor Support  rcl: 2
# created : Interim Contractor Support
#
# Contractor Logistics Support (CLS)  rcl: 1
# Exiting 2
# Contractor Logistics Support (CLS)  rcl: 1
#
# Contractor Logistics Support (CLS)  rcl: 1
# Contractor Logistics Support (CLS)  rcl: 1
# row: {'Tc_Level': 1, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Contractor Logistics Support (CLS) '}
# last_row False
# Contractor Logistics Support (CLS)  rcl: 1
# Contractor Logistics Support (CLS)  rcl: 1
# current row : Contractor Logistics Support (CLS)  rcl: 1 cl: 1
# Contractor Logistics Support (CLS)  rcl: 1
# Contractor Logistics Support (CLS)  rcl: 1
# Contractor Logistics Support (CLS)  rcl: 1
# Contractor Logistics Support (CLS)  rcl: 1
# created : Contractor Logistics Support (CLS)
#
# Industrial Facilities  rcl: 1
# Industrial Facilities  rcl: 1
# row: {'Tc_Level': 1, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Industrial Facilities '}
# last_row False
# Industrial Facilities  rcl: 1
# Industrial Facilities  rcl: 1
# current row : Industrial Facilities  rcl: 1 cl: 1
# Industrial Facilities  rcl: 1
# Industrial Facilities  rcl: 1
# Industrial Facilities  rcl: 1
# Industrial Facilities  rcl: 1
# created : Industrial Facilities
#
# Construction/Conversion/Expansion  rcl: 2
# Construction/Conversion/Expansion  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Construction/Conversion/Expansion '}
# last_row False
# Construction/Conversion/Expansion  rcl: 2
# Construction/Conversion/Expansion  rcl: 2
# current row : Construction/Conversion/Expansion  rcl: 2 cl: 1
# Construction/Conversion/Expansion  rcl: 2
# Construction/Conversion/Expansion  rcl: 2
#
# Entering cl 2
# Construction/Conversion/Expansion  rcl: 2
# Construction/Conversion/Expansion  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Construction/Conversion/Expansion '}
# last_row False
# Construction/Conversion/Expansion  rcl: 2
# Construction/Conversion/Expansion  rcl: 2
# current row : Construction/Conversion/Expansion  rcl: 2 cl: 2
# Construction/Conversion/Expansion  rcl: 2
# Construction/Conversion/Expansion  rcl: 2
# Construction/Conversion/Expansion  rcl: 2
# Construction/Conversion/Expansion  rcl: 2
# created : Construction/Conversion/Expansion
#
# Equipment Acquisition or Modernization  rcl: 2
# Equipment Acquisition or Modernization  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Equipment Acquisition or Modernization '}
# last_row False
# Equipment Acquisition or Modernization  rcl: 2
# Equipment Acquisition or Modernization  rcl: 2
# current row : Equipment Acquisition or Modernization  rcl: 2 cl: 2
# Equipment Acquisition or Modernization  rcl: 2
# Equipment Acquisition or Modernization  rcl: 2
# Equipment Acquisition or Modernization  rcl: 2
# Equipment Acquisition or Modernization  rcl: 2
# created : Equipment Acquisition or Modernization
#
# Maintenance (Industrial Facilities)  rcl: 2
# Maintenance (Industrial Facilities)  rcl: 2
# row: {'Tc_Level': 2, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Maintenance (Industrial Facilities) '}
# last_row False
# Maintenance (Industrial Facilities)  rcl: 2
# Maintenance (Industrial Facilities)  rcl: 2
# current row : Maintenance (Industrial Facilities)  rcl: 2 cl: 2
# Maintenance (Industrial Facilities)  rcl: 2
# Maintenance (Industrial Facilities)  rcl: 2
# Maintenance (Industrial Facilities)  rcl: 2
# Maintenance (Industrial Facilities)  rcl: 2
# created : Maintenance (Industrial Facilities)
#
# Initial Spares and Repair Parts rcl: 1
# Exiting 2
# Initial Spares and Repair Parts rcl: 1
#
# Initial Spares and Repair Parts rcl: 1
# Initial Spares and Repair Parts rcl: 1
# row: {'Tc_Level': 1, 'Tc_ObjectType': 'Fnd0LogicalBlock', 'Title': 'Initial Spares and Repair Parts'}
# last_row False
# Initial Spares and Repair Parts rcl: 1
# Initial Spares and Repair Parts rcl: 1
# current row : Initial Spares and Repair Parts rcl: 1 cl: 1
# Initial Spares and Repair Parts rcl: 1
# Initial Spares and Repair Parts rcl: 1
# Initial Spares and Repair Parts rcl: 1
# Initial Spares and Repair Parts rcl: 1
# created : Initial Spares and Repair Parts
#
# Exiting 1
# Index 108 is out of bounds.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 191
#     188 row = excel_content.get_first_row()
#     189 current_level = 0
# --> 191 Create_Component_Level(current_level,parent,excel_content)
#
# Cell In[2], line 176, in Create_Component_Level(current_level, parent, excel_content)
#     174     current_level = int(excel_content.get_current_row()["Tc_Level"])
#     175     parent = new_lc
# --> 176     Create_Component_Level(current_level,parent,excel_content)
#     177     current_level = int(excel_content.get_current_row()["Tc_Level"])
#     178 else :
#
# Cell In[2], line 176, in Create_Component_Level(current_level, parent, excel_content)
#     174     current_level = int(excel_content.get_current_row()["Tc_Level"])
#     175     parent = new_lc
# --> 176     Create_Component_Level(current_level,parent,excel_content)
#     177     current_level = int(excel_content.get_current_row()["Tc_Level"])
#     178 else :
#
# Cell In[2], line 177, in Create_Component_Level(current_level, parent, excel_content)
#     175     parent = new_lc
#     176     Create_Component_Level(current_level,parent,excel_content)
# --> 177     current_level = int(excel_content.get_current_row()["Tc_Level"])
#     178 else :
#     179     current_level = int(excel_content.get_current_row()["Tc_Level"])
#
# TypeError: 'NoneType' object is not subscriptable
